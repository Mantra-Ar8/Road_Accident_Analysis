# %%
import os
import pickle
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

DATA_PATH = r"C:\Users\KIIT\Desktop\1\RoadAccidentsInIndia\ModifiedDatabase\typeOfVehicle.csv"
assert os.path.exists(DATA_PATH), f"File not found: {DATA_PATH}"

df = pd.read_csv(DATA_PATH)
print("Loaded:", DATA_PATH, "shape:", df.shape)
display(df.head())
# Out:
# Loaded: C:\Users\KIIT\Desktop\1\RoadAccidentsInIndia\ModifiedDatabase\typeOfVehicle.csv shape: (37, 59)
#   Sl. No.         States/UTs  \
# 0       1     Andhra Pradesh
# 1       2  Arunachal Pradesh
# 2       3              Assam
# 3       4              Bihar
# 4       5       Chhattisgarh
#
#    Two-Wheelers - Number of Road Accidents - Fatal - 2014  \
# 0                                               1961
# 1                                                 15
# 2                                                489
# 3                                                769
# 4                                               1074
#
#    Two-Wheelers - Number of Road Accidents - Fatal - 2014 per 1L people  \
# 0                                           3.741606
# 1                                           1.084029
# 2                                           1.567028
# 3                                           0.738717
# 4                                           4.204313
#
#    Two-Wheelers - Number of Road Accidents - Total - 2014  \
# 0                                               7239
# 1                                                 34
# 2                                               1508
# 3                                               1750
# 4                                               4787
#
#    Two-Wheelers - Number of Road Accidents - Total - 2014 per 1L people  \
# 0                                          13.812077
# 1                                           2.457132
# 2                                           4.832470
# 3                                           1.681085
# 4                                          18.739334
#
#    Two-Wheelers - Number of Persons - Killed - 2014  \
# 0                                              2003
# 1                                                21
# 2                                               537
# 3                                               820
# 4                                              1126
#
#    Two-Wheelers - Number of Persons - Killed - 2014 per 1L people  \
# 0                                           3.821742
# 1                                           1.517640
# 2                                           1.720846
# 3                                           0.787708
# 4                                           4.407873
#
#    Two-Wheelers - Number of Persons - Injured - 2014  \
# 0                                               7333
# 1                                                 30
# 2                                               1342
# 3                                               1131
# 4                                               4295
#
#    Two-Wheelers - Number of Persons - Injured - 2014 per 1L people  ...  \
# 0                                          13.991430                ...
# 1                                           2.168058                ...
# 2                                           4.300513                ...
# 3                                           1.086461                ...
# 4                                          16.813336                ...
#
#    Other Motor Vehicles - Number of Persons - Injured - 2014 per 1L people  \
# 0                                           2.520480
# 1                                           0.000000
# 2                                           2.868077
# 3                                           0.425555
# 4                                           4.662324
#
#    Other Vehicles/Objects - Number of Road Accidents - Fatal - 2014  \
# 0                                                466
# 1                                                 27
# 2                                                 73
# 3                                                614
# 4                                                142
#
#    Other Vehicles/Objects - Number of Road Accidents - Fatal - 2014 per 1L people  \
# 0                                           0.889132
# 1                                           1.951252
# 2                                           0.233933
# 3                                           0.589821
# 4                                           0.555877
#
#    Other Vehicles/Objects - Number of Road Accidents - Total - 2014  \
# 0                                               1279
# 1                                                 55
# 2                                                249
# 3                                               1577
# 4                                                515
#
#    Other Vehicles/Objects - Number of Road Accidents - Total - 2014 per 1L people  \
# 0                                           2.440344
# 1                                           3.974772
# 2                                           0.797934
# 3                                           1.514898
# 4                                           2.016034
#
#    Other Vehicles/Objects - Number of Persons - Killed - 2014  \
# 0                                                884
# 1                                                 33
# 2                                                 93
# 3                                                690
# 4                                                154
#
#    Other Vehicles/Objects - Number of Persons - Killed - 2014 per 1L people  \
# 0                                           1.686680
# 1                                           2.384863
# 2                                           0.298024
# 3                                           0.662828
# 4                                           0.602853
#
#    Other Vehicles/Objects - Number of Persons - Injured - 2014  \
# 0                                               1289
# 1                                                 58
# 2                                                218
# 3                                               1165
# 4                                                438
#
#    Other Vehicles/Objects - Number of Persons - Injured - 2014 per 1L people  \
# 0                                           2.459424
# 1                                           4.191578
# 2                                           0.698593
# 3                                           1.119122
# 4                                           1.714608
#
#    Population
# 0    52410653
# 1     1383727
# 2    31205576
# 3   104099452
# 4    25545198
#
# [5 rows x 59 columns]

# %%
pd.set_option('display.max_columns', 200)
print("Columns (count={}):".format(len(df.columns)))
for i,c in enumerate(df.columns):
    print(f"{i+1:02d}. {c}  (dtype={df[c].dtype}, non-null={df[c].notna().sum()}, unique={df[c].nunique(dropna=True)})")


display(df.describe(include='all').T)
# Out:
# Columns (count=59):
# 01. Sl. No.  (dtype=object, non-null=37, unique=37)
# 02. States/UTs  (dtype=object, non-null=37, unique=37)
# 03. Two-Wheelers - Number of Road Accidents - Fatal - 2014  (dtype=int64, non-null=37, unique=36)
# 04. Two-Wheelers - Number of Road Accidents - Fatal - 2014 per 1L people  (dtype=float64, non-null=37, unique=37)
# 05. Two-Wheelers - Number of Road Accidents - Total - 2014  (dtype=int64, non-null=37, unique=37)
# 06. Two-Wheelers - Number of Road Accidents - Total - 2014 per 1L people  (dtype=float64, non-null=37, unique=37)
# 07. Two-Wheelers - Number of Persons - Killed - 2014  (dtype=int64, non-null=37, unique=35)
# 08. Two-Wheelers - Number of Persons - Killed - 2014 per 1L people  (dtype=float64, non-null=37, unique=37)
# 09. Two-Wheelers - Number of Persons - Injured - 2014  (dtype=int64, non-null=37, unique=36)
# 10. Two-Wheelers - Number of Persons - Injured - 2014 per 1L people  (dtype=float64, non-null=37, unique=37)
# 11. Auto-Rickshaws - Number of Road Accidents - Fatal - 2014  (dtype=int64, non-null=37, unique=32)
# 12. Auto-Rickshaws - Number of Road Accidents - Fatal - 2014 per 1L people  (dtype=float64, non-null=37, unique=34)
# 13. Auto-Rickshaws - Number of Road Accidents - Total - 2014  (dtype=int64, non-null=37, unique=36)
# 14. Auto-Rickshaws - Number of Road Accidents - Total - 2014 per 1L people  (dtype=float64, non-null=37, unique=36)
# 15. Auto-Rickshaws - Number of Persons - Killed - 2014  (dtype=int64, non-null=37, unique=30)
# 16. Auto-Rickshaws - Number of Persons - Killed - 2014 per 1L people  (dtype=float64, non-null=37, unique=34)
# 17. Auto-Rickshaws - Number of Persons - Injured - 2014  (dtype=int64, non-null=37, unique=31)
# 18. Auto-Rickshaws - Number of Persons - Injured - 2014 per 1L people  (dtype=float64, non-null=37, unique=36)
# 19. Cars, Jeeps,Taxis - Number of Road Accidents - Fatal - 2014  (dtype=int64, non-null=37, unique=33)
# 20. Cars, Jeeps,Taxis - Number of Road Accidents - Fatal - 2014 per 1L people  (dtype=float64, non-null=37, unique=36)
# 21. Cars, Jeeps,Taxis - Number of Road Accidents - Total - 2014  (dtype=int64, non-null=37, unique=37)
# 22. Cars, Jeeps,Taxis - Number of Road Accidents - Total - 2014 per 1L people  (dtype=float64, non-null=37, unique=37)
# 23. Cars, Jeeps,Taxis - Number of Persons - Killed - 2014  (dtype=int64, non-null=37, unique=34)
# 24. Cars, Jeeps,Taxis - Number of Persons - Killed - 2014 per 1L people  (dtype=float64, non-null=37, unique=36)
# 25. Cars, Jeeps,Taxis - Number of Persons - Injured - 2014  (dtype=int64, non-null=37, unique=37)
# 26. Cars, Jeeps,Taxis - Number of Persons - Injured - 2014 per 1L people  (dtype=float64, non-null=37, unique=37)
# 27. Buses - Number of Road Accidents - Fatal - 2014  (dtype=int64, non-null=37, unique=32)
# 28. Buses - Number of Road Accidents - Fatal - 2014 per 1L people  (dtype=float64, non-null=37, unique=36)
# 29. Buses - Number of Road Accidents - Total - 2014  (dtype=int64, non-null=37, unique=34)
# 30. Buses - Number of Road Accidents - Total - 2014 per 1L people  (dtype=float64, non-null=37, unique=36)
# 31. Buses - Number of Persons - Killed - 2014  (dtype=int64, non-null=37, unique=34)
# 32. Buses - Number of Persons - Killed - 2014 per 1L people  (dtype=float64, non-null=37, unique=36)
# 33. Buses - Number of Persons - Injured - 2014  (dtype=int64, non-null=37, unique=35)
# 34. Buses - Number of Persons - Injured - 2014 per 1L people  (dtype=float64, non-null=37, unique=35)
# 35. Trucks, Tempos,MAVs,Tractors - Number of Road Accidents - Fatal - 2014  (dtype=int64, non-null=37, unique=33)
# 36. Trucks, Tempos,MAVs,Tractors - Number of Road Accidents - Fatal - 2014 per 1L people  (dtype=float64, non-null=37, unique=36)
# 37. Trucks, Tempos,MAVs,Tractors - Number of Road Accidents - Total - 2014  (dtype=int64, non-null=37, unique=35)
# 38. Trucks, Tempos,MAVs,Tractors - Number of Road Accidents - Total - 2014 per 1L people  (dtype=float64, non-null=37, unique=36)
# 39. Trucks, Tempos,MAVs,Tractors - Number of Persons - Killed - 2014  (dtype=int64, non-null=37, unique=36)
# 40. Trucks, Tempos,MAVs,Tractors - Number of Persons - Killed - 2014 per 1L people  (dtype=float64, non-null=37, unique=36)
# 41. Trucks, Tempos,MAVs,Tractors - Number of Persons - Injured - 2014  (dtype=int64, non-null=37, unique=36)
# 42. Trucks, Tempos,MAVs,Tractors - Number of Persons - Injured - 2014 per 1L people  (dtype=float64, non-null=37, unique=36)
# 43. Other Motor Vehicles - Number of Road Accidents - Fatal - 2014  (dtype=int64, non-null=37, unique=31)
# 44. Other Motor Vehicles - Number of Road Accidents - Fatal - 2014 per 1L people  (dtype=float64, non-null=37, unique=34)
# 45. Other Motor Vehicles - Number of Road Accidents - Total - 2014  (dtype=int64, non-null=37, unique=35)
# 46. Other Motor Vehicles - Number of Road Accidents - Total - 2014 per 1L people  (dtype=float64, non-null=37, unique=35)
# 47. Other Motor Vehicles - Number of Persons - Killed - 2014  (dtype=int64, non-null=37, unique=34)
# 48. Other Motor Vehicles - Number of Persons - Killed - 2014 per 1L people  (dtype=float64, non-null=37, unique=34)
# 49. Other Motor Vehicles - Number of Persons - Injured - 2014  (dtype=int64, non-null=37, unique=34)
# 50. Other Motor Vehicles - Number of Persons - Injured - 2014 per 1L people  (dtype=float64, non-null=37, unique=34)
# 51. Other Vehicles/Objects - Number of Road Accidents - Fatal - 2014  (dtype=int64, non-null=37, unique=26)
# 52. Other Vehicles/Objects - Number of Road Accidents - Fatal - 2014 per 1L people  (dtype=float64, non-null=37, unique=28)
# 53. Other Vehicles/Objects - Number of Road Accidents - Total - 2014  (dtype=int64, non-null=37, unique=27)
# 54. Other Vehicles/Objects - Number of Road Accidents - Total - 2014 per 1L people  (dtype=float64, non-null=37, unique=29)
# 55. Other Vehicles/Objects - Number of Persons - Killed - 2014  (dtype=int64, non-null=37, unique=27)
# 56. Other Vehicles/Objects - Number of Persons - Killed - 2014 per 1L people  (dtype=float64, non-null=37, unique=28)
# 57. Other Vehicles/Objects - Number of Persons - Injured - 2014  (dtype=int64, non-null=37, unique=27)
# 58. Other Vehicles/Objects - Number of Persons - Injured - 2014 per 1L people  (dtype=float64, non-null=37, unique=27)
# 59. Population  (dtype=int64, non-null=37, unique=37)
#                                                    count unique  \
# Sl. No.                                               37     37
# States/UTs                                            37     37
# Two-Wheelers - Number of Road Accidents - Fatal...  37.0    NaN
# Two-Wheelers - Number of Road Accidents - Fatal...  37.0    NaN
# Two-Wheelers - Number of Road Accidents - Total...  37.0    NaN
# Two-Wheelers - Number of Road Accidents - Total...  37.0    NaN
# Two-Wheelers - Number of Persons - Killed - 2014    37.0    NaN
# Two-Wheelers - Number of Persons - Killed - 201...  37.0    NaN
# Two-Wheelers - Number of Persons - Injured - 2014   37.0    NaN
# Two-Wheelers - Number of Persons - Injured - 20...  37.0    NaN
# Auto-Rickshaws - Number of Road Accidents - Fat...  37.0    NaN
# Auto-Rickshaws - Number of Road Accidents - Fat...  37.0    NaN
# Auto-Rickshaws - Number of Road Accidents - Tot...  37.0    NaN
# Auto-Rickshaws - Number of Road Accidents - Tot...  37.0    NaN
# Auto-Rickshaws - Number of Persons - Killed - 2014  37.0    NaN
# Auto-Rickshaws - Number of Persons - Killed - 2...  37.0    NaN
# Auto-Rickshaws - Number of Persons - Injured - ...  37.0    NaN
# Auto-Rickshaws - Number of Persons - Injured - ...  37.0    NaN
# Cars, Jeeps,Taxis - Number of Road Accidents - ...  37.0    NaN
# Cars, Jeeps,Taxis - Number of Road Accidents - ...  37.0    NaN
# Cars, Jeeps,Taxis - Number of Road Accidents - ...  37.0    NaN
# Cars, Jeeps,Taxis - Number of Road Accidents - ...  37.0    NaN
# Cars, Jeeps,Taxis - Number of Persons - Killed ...  37.0    NaN
# Cars, Jeeps,Taxis - Number of Persons - Killed ...  37.0    NaN
# Cars, Jeeps,Taxis - Number of Persons - Injured...  37.0    NaN
# Cars, Jeeps,Taxis - Number of Persons - Injured...  37.0    NaN
# Buses - Number of Road Accidents - Fatal - 2014     37.0    NaN
# Buses - Number of Road Accidents - Fatal - 2014...  37.0    NaN
# Buses - Number of Road Accidents - Total - 2014     37.0    NaN
# Buses - Number of Road Accidents - Total - 2014...  37.0    NaN
# Buses - Number of Persons - Killed - 2014           37.0    NaN
# Buses - Number of Persons - Killed - 2014 per 1...  37.0    NaN
# Buses - Number of Persons - Injured - 2014          37.0    NaN
# Buses - Number of Persons - Injured - 2014 per ...  37.0    NaN
# Trucks, Tempos,MAVs,Tractors - Number of Road A...  37.0    NaN
# Trucks, Tempos,MAVs,Tractors - Number of Road A...  37.0    NaN
# Trucks, Tempos,MAVs,Tractors - Number of Road A...  37.0    NaN
# Trucks, Tempos,MAVs,Tractors - Number of Road A...  37.0    NaN
# Trucks, Tempos,MAVs,Tractors - Number of Person...  37.0    NaN
# Trucks, Tempos,MAVs,Tractors - Number of Person...  37.0    NaN
# Trucks, Tempos,MAVs,Tractors - Number of Person...  37.0    NaN
# Trucks, Tempos,MAVs,Tractors - Number of Person...  37.0    NaN
# Other Motor Vehicles - Number of Road Accidents...  37.0    NaN
# Other Motor Vehicles - Number of Road Accidents...  37.0    NaN
# Other Motor Vehicles - Number of Road Accidents...  37.0    NaN
# Other Motor Vehicles - Number of Road Accidents...  37.0    NaN
# Other Motor Vehicles - Number of Persons - Kill...  37.0    NaN
# Other Motor Vehicles - Number of Persons - Kill...  37.0    NaN
# Other Motor Vehicles - Number of Persons - Inju...  37.0    NaN
# Other Motor Vehicles - Number of Persons - Inju...  37.0    NaN
# Other Vehicles/Objects - Number of Road Acciden...  37.0    NaN
# Other Vehicles/Objects - Number of Road Acciden...  37.0    NaN
# Other Vehicles/Objects - Number of Road Acciden...  37.0    NaN
# Other Vehicles/Objects - Number of Road Acciden...  37.0    NaN
# Other Vehicles/Objects - Number of Persons - Ki...  37.0    NaN
# Other Vehicles/Objects - Number of Persons - Ki...  37.0    NaN
# Other Vehicles/Objects - Number of Persons - In...  37.0    NaN
# Other Vehicles/Objects - Number of Persons - In...  37.0    NaN
# Population                                          37.0    NaN
#
#                                                                top freq  \
# Sl. No.                                                          1    1
# States/UTs                                          Andhra Pradesh    1
# Two-Wheelers - Number of Road Accidents - Fatal...             NaN  NaN
# Two-Wheelers - Number of Road Accidents - Fatal...             NaN  NaN
# Two-Wheelers - Number of Road Accidents - Total...             NaN  NaN
# Two-Wheelers - Number of Road Accidents - Total...             NaN  NaN
# Two-Wheelers - Number of Persons - Killed - 2014               NaN  NaN
# Two-Wheelers - Number of Persons - Killed - 201...             NaN  NaN
# Two-Wheelers - Number of Persons - Injured - 2014              NaN  NaN
# Two-Wheelers - Number of Persons - Injured - 20...             NaN  NaN
# Auto-Rickshaws - Number of Road Accidents - Fat...             NaN  NaN
# Auto-Rickshaws - Number of Road Accidents - Fat...             NaN  NaN
# Auto-Rickshaws - Number of Road Accidents - Tot...             NaN  NaN
# Auto-Rickshaws - Number of Road Accidents - Tot...             NaN  NaN
# Auto-Rickshaws - Number of Persons - Killed - 2014             NaN  NaN
# Auto-Rickshaws - Number of Persons - Killed - 2...             NaN  NaN
# Auto-Rickshaws - Number of Persons - Injured - ...             NaN  NaN
# Auto-Rickshaws - Number of Persons - Injured - ...             NaN  NaN
# Cars, Jeeps,Taxis - Number of Road Accidents - ...             NaN  NaN
# Cars, Jeeps,Taxis - Number of Road Accidents - ...             NaN  NaN
# Cars, Jeeps,Taxis - Number of Road Accidents - ...             NaN  NaN
# Cars, Jeeps,Taxis - Number of Road Accidents - ...             NaN  NaN
# Cars, Jeeps,Taxis - Number of Persons - Killed ...             NaN  NaN
# Cars, Jeeps,Taxis - Number of Persons - Killed ...             NaN  NaN
# Cars, Jeeps,Taxis - Number of Persons - Injured...             NaN  NaN
# Cars, Jeeps,Taxis - Number of Persons - Injured...             NaN  NaN
# Buses - Number of Road Accidents - Fatal - 2014                NaN  NaN
# Buses - Number of Road Accidents - Fatal - 2014...             NaN  NaN
# Buses - Number of Road Accidents - Total - 2014                NaN  NaN
# Buses - Number of Road Accidents - Total - 2014...             NaN  NaN
# Buses - Number of Persons - Killed - 2014                      NaN  NaN
# Buses - Number of Persons - Killed - 2014 per 1...             NaN  NaN
# Buses - Number of Persons - Injured - 2014                     NaN  NaN
# Buses - Number of Persons - Injured - 2014 per ...             NaN  NaN
# Trucks, Tempos,MAVs,Tractors - Number of Road A...             NaN  NaN
# Trucks, Tempos,MAVs,Tractors - Number of Road A...             NaN  NaN
# Trucks, Tempos,MAVs,Tractors - Number of Road A...             NaN  NaN
# Trucks, Tempos,MAVs,Tractors - Number of Road A...             NaN  NaN
# Trucks, Tempos,MAVs,Tractors - Number of Person...             NaN  NaN
# Trucks, Tempos,MAVs,Tractors - Number of Person...             NaN  NaN
# Trucks, Tempos,MAVs,Tractors - Number of Person...             NaN  NaN
# Trucks, Tempos,MAVs,Tractors - Number of Person...             NaN  NaN
# Other Motor Vehicles - Number of Road Accidents...             NaN  NaN
# Other Motor Vehicles - Number of Road Accidents...             NaN  NaN
# Other Motor Vehicles - Number of Road Accidents...             NaN  NaN
# Other Motor Vehicles - Number of Road Accidents...             NaN  NaN
# Other Motor Vehicles - Number of Persons - Kill...             NaN  NaN
# Other Motor Vehicles - Number of Persons - Kill...             NaN  NaN
# Other Motor Vehicles - Number of Persons - Inju...             NaN  NaN
# Other Motor Vehicles - Number of Persons - Inju...             NaN  NaN
# Other Vehicles/Objects - Number of Road Acciden...             NaN  NaN
# Other Vehicles/Objects - Number of Road Acciden...             NaN  NaN
# Other Vehicles/Objects - Number of Road Acciden...             NaN  NaN
# Other Vehicles/Objects - Number of Road Acciden...             NaN  NaN
# Other Vehicles/Objects - Number of Persons - Ki...             NaN  NaN
# Other Vehicles/Objects - Number of Persons - Ki...             NaN  NaN
# Other Vehicles/Objects - Number of Persons - In...             NaN  NaN
# Other Vehicles/Objects - Number of Persons - In...             NaN  NaN
# Population                                                     NaN  NaN
#
#                                                                mean  \
# Sl. No.                                                         NaN
# States/UTs                                                      NaN
# Two-Wheelers - Number of Road Accidents - Fatal...      1625.081081
# Two-Wheelers - Number of Road Accidents - Fatal...         2.364123
# Two-Wheelers - Number of Road Accidents - Total...      7223.459459
# Two-Wheelers - Number of Road Accidents - Total...        13.724032
# Two-Wheelers - Number of Persons - Killed - 2014        1758.054054
# Two-Wheelers - Number of Persons - Killed - 201...         2.555299
# Two-Wheelers - Number of Persons - Injured - 2014       6889.297297
# Two-Wheelers - Number of Persons - Injured - 20...        11.905215
# Auto-Rickshaws - Number of Road Accidents - Fat...       300.162162
# Auto-Rickshaws - Number of Road Accidents - Fat...         0.479302
# Auto-Rickshaws - Number of Road Accidents - Tot...      1684.972973
# Auto-Rickshaws - Number of Road Accidents - Tot...         2.644255
# Auto-Rickshaws - Number of Persons - Killed - 2014       339.405405
# Auto-Rickshaws - Number of Persons - Killed - 2...         0.545547
# Auto-Rickshaws - Number of Persons - Injured - ...           2208.0
# Auto-Rickshaws - Number of Persons - Injured - ...         3.589946
# Cars, Jeeps,Taxis - Number of Road Accidents - ...      1232.594595
# Cars, Jeeps,Taxis - Number of Road Accidents - ...         2.006111
# Cars, Jeeps,Taxis - Number of Road Accidents - ...      6011.783784
# Cars, Jeeps,Taxis - Number of Road Accidents - ...        11.313873
# Cars, Jeeps,Taxis - Number of Persons - Killed ...      1407.459459
# Cars, Jeeps,Taxis - Number of Persons - Killed ...         2.337515
# Cars, Jeeps,Taxis - Number of Persons - Injured...      6130.432432
# Cars, Jeeps,Taxis - Number of Persons - Injured...        11.375895
# Buses - Number of Road Accidents - Fatal - 2014          578.918919
# Buses - Number of Road Accidents - Fatal - 2014...         0.850845
# Buses - Number of Road Accidents - Total - 2014         2235.945946
# Buses - Number of Road Accidents - Total - 2014...         3.866573
# Buses - Number of Persons - Killed - 2014                658.648649
# Buses - Number of Persons - Killed - 2014 per 1...         0.964952
# Buses - Number of Persons - Injured - 2014                   2776.0
# Buses - Number of Persons - Injured - 2014 per ...         4.803336
# Trucks, Tempos,MAVs,Tractors - Number of Road A...      1734.108108
# Trucks, Tempos,MAVs,Tractors - Number of Road A...         2.408152
# Trucks, Tempos,MAVs,Tractors - Number of Road A...      5200.810811
# Trucks, Tempos,MAVs,Tractors - Number of Road A...         7.257249
# Trucks, Tempos,MAVs,Tractors - Number of Person...      1930.324324
# Trucks, Tempos,MAVs,Tractors - Number of Person...         2.633642
# Trucks, Tempos,MAVs,Tractors - Number of Person...      5109.837838
# Trucks, Tempos,MAVs,Tractors - Number of Person...         7.470984
# Other Motor Vehicles - Number of Road Accidents...       789.351351
# Other Motor Vehicles - Number of Road Accidents...         1.146276
# Other Motor Vehicles - Number of Road Accidents...      2377.351351
# Other Motor Vehicles - Number of Road Accidents...         3.558899
# Other Motor Vehicles - Number of Persons - Kill...       831.351351
# Other Motor Vehicles - Number of Persons - Kill...         1.271974
# Other Motor Vehicles - Number of Persons - Inju...      2108.432432
# Other Motor Vehicles - Number of Persons - Inju...         4.216347
# Other Vehicles/Objects - Number of Road Acciden...       541.297297
# Other Vehicles/Objects - Number of Road Acciden...         0.699173
# Other Vehicles/Objects - Number of Road Acciden...       1719.72973
# Other Vehicles/Objects - Number of Road Acciden...         2.392607
# Other Vehicles/Objects - Number of Persons - Ki...       624.540541
# Other Vehicles/Objects - Number of Persons - Ki...         0.766393
# Other Vehicles/Objects - Number of Persons - In...       1452.27027
# Other Vehicles/Objects - Number of Persons - In...          1.86734
# Population                                          65453911.081081
#
#                                                                  std  \
# Sl. No.                                                          NaN
# States/UTs                                                       NaN
# Two-Wheelers - Number of Road Accidents - Fatal...       4928.288707
# Two-Wheelers - Number of Road Accidents - Fatal...          1.773977
# Two-Wheelers - Number of Road Accidents - Total...      22096.152669
# Two-Wheelers - Number of Road Accidents - Total...         22.256395
# Two-Wheelers - Number of Persons - Killed - 2014         5331.111256
# Two-Wheelers - Number of Persons - Killed - 201...          1.866243
# Two-Wheelers - Number of Persons - Injured - 2014        21158.70558
# Two-Wheelers - Number of Persons - Injured - 20...         13.388724
# Auto-Rickshaws - Number of Road Accidents - Fat...        915.572817
# Auto-Rickshaws - Number of Road Accidents - Fat...           0.64212
# Auto-Rickshaws - Number of Road Accidents - Tot...       5157.921591
# Auto-Rickshaws - Number of Road Accidents - Tot...          3.347934
# Auto-Rickshaws - Number of Persons - Killed - 2014       1034.619803
# Auto-Rickshaws - Number of Persons - Killed - 2...          0.798823
# Auto-Rickshaws - Number of Persons - Injured - ...        6776.93407
# Auto-Rickshaws - Number of Persons - Injured - ...          4.787489
# Cars, Jeeps,Taxis - Number of Road Accidents - ...       3730.891303
# Cars, Jeeps,Taxis - Number of Road Accidents - ...          1.348958
# Cars, Jeeps,Taxis - Number of Road Accidents - ...      18374.086295
# Cars, Jeeps,Taxis - Number of Road Accidents - ...         15.609175
# Cars, Jeeps,Taxis - Number of Persons - Killed ...       4257.930317
# Cars, Jeeps,Taxis - Number of Persons - Killed ...          1.599839
# Cars, Jeeps,Taxis - Number of Persons - Injured...      18754.871409
# Cars, Jeeps,Taxis - Number of Persons - Injured...          10.14054
# Buses - Number of Road Accidents - Fatal - 2014          1754.986062
# Buses - Number of Road Accidents - Fatal - 2014...          0.583149
# Buses - Number of Road Accidents - Total - 2014          6805.008788
# Buses - Number of Road Accidents - Total - 2014...          4.758312
# Buses - Number of Persons - Killed - 2014                1994.422559
# Buses - Number of Persons - Killed - 2014 per 1...          0.640982
# Buses - Number of Persons - Injured - 2014               8491.541573
# Buses - Number of Persons - Injured - 2014 per ...          5.259167
# Trucks, Tempos,MAVs,Tractors - Number of Road A...        5228.80707
# Trucks, Tempos,MAVs,Tractors - Number of Road A...           1.45915
# Trucks, Tempos,MAVs,Tractors - Number of Road A...      15722.652932
# Trucks, Tempos,MAVs,Tractors - Number of Road A...          4.847937
# Trucks, Tempos,MAVs,Tractors - Number of Person...       5823.730811
# Trucks, Tempos,MAVs,Tractors - Number of Person...          1.581531
# Trucks, Tempos,MAVs,Tractors - Number of Person...      15476.784554
# Trucks, Tempos,MAVs,Tractors - Number of Person...           4.95782
# Other Motor Vehicles - Number of Road Accidents...       2384.941628
# Other Motor Vehicles - Number of Road Accidents...          0.766591
# Other Motor Vehicles - Number of Road Accidents...       7233.756559
# Other Motor Vehicles - Number of Road Accidents...          2.354834
# Other Motor Vehicles - Number of Persons - Kill...       2511.521586
# Other Motor Vehicles - Number of Persons - Kill...          0.856439
# Other Motor Vehicles - Number of Persons - Inju...       6427.443295
# Other Motor Vehicles - Number of Persons - Inju...          4.982607
# Other Vehicles/Objects - Number of Road Acciden...       1651.275178
# Other Vehicles/Objects - Number of Road Acciden...          0.890842
# Other Vehicles/Objects - Number of Road Acciden...       5260.215404
# Other Vehicles/Objects - Number of Road Acciden...          3.672172
# Other Vehicles/Objects - Number of Persons - Ki...        1913.50469
# Other Vehicles/Objects - Number of Persons - Ki...          0.942906
# Other Vehicles/Objects - Number of Persons - In...       4445.142609
# Other Vehicles/Objects - Number of Persons - In...          2.506844
# Population                                          198141512.377245
#
#                                                          min        25%  \
# Sl. No.                                                  NaN        NaN
# States/UTs                                               NaN        NaN
# Two-Wheelers - Number of Road Accidents - Fatal...       0.0       20.0
# Two-Wheelers - Number of Road Accidents - Fatal...       0.0   1.084029
# Two-Wheelers - Number of Road Accidents - Total...       1.0       92.0
# Two-Wheelers - Number of Road Accidents - Total...   1.51674   3.849857
# Two-Wheelers - Number of Persons - Killed - 2014         0.0       21.0
# Two-Wheelers - Number of Persons - Killed - 201...       0.0    1.24717
# Two-Wheelers - Number of Persons - Injured - 2014        1.0       98.0
# Two-Wheelers - Number of Persons - Injured - 20...  0.842633   2.729338
# Auto-Rickshaws - Number of Road Accidents - Fat...       0.0        5.0
# Auto-Rickshaws - Number of Road Accidents - Fat...       0.0   0.121354
# Auto-Rickshaws - Number of Road Accidents - Tot...       0.0       27.0
# Auto-Rickshaws - Number of Road Accidents - Tot...       0.0   0.716282
# Auto-Rickshaws - Number of Persons - Killed - 2014       0.0        5.0
# Auto-Rickshaws - Number of Persons - Killed - 2...       0.0   0.138329
# Auto-Rickshaws - Number of Persons - Injured - ...       0.0       36.0
# Auto-Rickshaws - Number of Persons - Injured - ...       0.0   0.742691
# Cars, Jeeps,Taxis - Number of Road Accidents - ...       0.0       35.0
# Cars, Jeeps,Taxis - Number of Road Accidents - ...       0.0   1.163775
# Cars, Jeeps,Taxis - Number of Road Accidents - ...       0.0      138.0
# Cars, Jeeps,Taxis - Number of Road Accidents - ...       0.0   3.707587
# Cars, Jeeps,Taxis - Number of Persons - Killed ...       0.0       38.0
# Cars, Jeeps,Taxis - Number of Persons - Killed ...       0.0   1.355521
# Cars, Jeeps,Taxis - Number of Persons - Injured...       0.0      182.0
# Cars, Jeeps,Taxis - Number of Persons - Injured...       0.0   4.111048
# Buses - Number of Road Accidents - Fatal - 2014          0.0        6.0
# Buses - Number of Road Accidents - Fatal - 2014...       0.0   0.455703
# Buses - Number of Road Accidents - Total - 2014          0.0       35.0
# Buses - Number of Road Accidents - Total - 2014...       0.0   1.330628
# Buses - Number of Persons - Killed - 2014                0.0       10.0
# Buses - Number of Persons - Killed - 2014 per 1...       0.0    0.50588
# Buses - Number of Persons - Injured - 2014               0.0       48.0
# Buses - Number of Persons - Injured - 2014 per ...       0.0   1.806606
# Trucks, Tempos,MAVs,Tractors - Number of Road A...       0.0       33.0
# Trucks, Tempos,MAVs,Tractors - Number of Road A...       0.0   1.461103
# Trucks, Tempos,MAVs,Tractors - Number of Road A...       0.0       77.0
# Trucks, Tempos,MAVs,Tractors - Number of Road A...       0.0    3.48402
# Trucks, Tempos,MAVs,Tractors - Number of Person...       0.0       33.0
# Trucks, Tempos,MAVs,Tractors - Number of Person...       0.0   1.750827
# Trucks, Tempos,MAVs,Tractors - Number of Person...       0.0       88.0
# Trucks, Tempos,MAVs,Tractors - Number of Person...       0.0   3.319716
# Other Motor Vehicles - Number of Road Accidents...       0.0       14.0
# Other Motor Vehicles - Number of Road Accidents...       0.0   0.545295
# Other Motor Vehicles - Number of Road Accidents...       0.0       48.0
# Other Motor Vehicles - Number of Road Accidents...       0.0   2.083383
# Other Motor Vehicles - Number of Persons - Kill...       0.0       17.0
# Other Motor Vehicles - Number of Persons - Kill...       0.0   0.674182
# Other Motor Vehicles - Number of Persons - Inju...       0.0       63.0
# Other Motor Vehicles - Number of Persons - Inju...       0.0   1.042209
# Other Vehicles/Objects - Number of Road Acciden...       0.0        0.0
# Other Vehicles/Objects - Number of Road Acciden...       0.0        0.0
# Other Vehicles/Objects - Number of Road Acciden...       0.0        1.0
# Other Vehicles/Objects - Number of Road Acciden...       0.0   0.014567
# Other Vehicles/Objects - Number of Persons - Ki...       0.0        0.0
# Other Vehicles/Objects - Number of Persons - Ki...       0.0        0.0
# Other Vehicles/Objects - Number of Persons - In...       0.0        0.0
# Other Vehicles/Objects - Number of Persons - In...       0.0        0.0
# Population                                           64473.0  1458545.0
#
#                                                            50%         75%  \
# Sl. No.                                                    NaN         NaN
# States/UTs                                                 NaN         NaN
# Two-Wheelers - Number of Road Accidents - Fatal...       300.0      1342.0
# Two-Wheelers - Number of Road Accidents - Fatal...    1.894926    3.305915
# Two-Wheelers - Number of Road Accidents - Total...      1305.0      4899.0
# Two-Wheelers - Number of Road Accidents - Total...    6.282428   13.812077
# Two-Wheelers - Number of Persons - Killed - 2014         318.0      1399.0
# Two-Wheelers - Number of Persons - Killed - 201...    2.041255    3.620044
# Two-Wheelers - Number of Persons - Injured - 2014       1083.0      4295.0
# Two-Wheelers - Number of Persons - Injured - 20...     7.20072    13.99143
# Auto-Rickshaws - Number of Road Accidents - Fat...        65.0       230.0
# Auto-Rickshaws - Number of Road Accidents - Fat...    0.323303    0.517159
# Auto-Rickshaws - Number of Road Accidents - Tot...       251.0      1476.0
# Auto-Rickshaws - Number of Road Accidents - Tot...    1.358118    2.959751
# Auto-Rickshaws - Number of Persons - Killed - 2014        75.0       265.0
# Auto-Rickshaws - Number of Persons - Killed - 2...    0.357362    0.581888
# Auto-Rickshaws - Number of Persons - Injured - ...       245.0      1314.0
# Auto-Rickshaws - Number of Persons - Injured - ...    1.447468    3.962724
# Cars, Jeeps,Taxis - Number of Road Accidents - ...       318.0      1000.0
# Cars, Jeeps,Taxis - Number of Road Accidents - ...    1.679777     2.53295
# Cars, Jeeps,Taxis - Number of Road Accidents - ...      1465.0      3853.0
# Cars, Jeeps,Taxis - Number of Road Accidents - ...    7.304802   15.239857
# Cars, Jeeps,Taxis - Number of Persons - Killed ...       444.0      1065.0
# Cars, Jeeps,Taxis - Number of Persons - Killed ...    1.792224    2.824379
# Cars, Jeeps,Taxis - Number of Persons - Injured...      1120.0      4620.0
# Cars, Jeeps,Taxis - Number of Persons - Injured...    8.111234   16.002355
# Buses - Number of Road Accidents - Fatal - 2014          148.0       481.0
# Buses - Number of Road Accidents - Fatal - 2014...    0.723081    1.193079
# Buses - Number of Road Accidents - Total - 2014          592.0      1590.0
# Buses - Number of Road Accidents - Total - 2014...    2.014898    4.517146
# Buses - Number of Persons - Killed - 2014                189.0       543.0
# Buses - Number of Persons - Killed - 2014 per 1...    0.790962      1.3017
# Buses - Number of Persons - Injured - 2014               617.0      1649.0
# Buses - Number of Persons - Injured - 2014 per ...     2.79219    5.206458
# Trucks, Tempos,MAVs,Tractors - Number of Road A...       517.0      1701.0
# Trucks, Tempos,MAVs,Tractors - Number of Road A...    2.137132    3.245523
# Trucks, Tempos,MAVs,Tractors - Number of Road A...      1384.0      4324.0
# Trucks, Tempos,MAVs,Tractors - Number of Road A...    5.659245   10.876064
# Trucks, Tempos,MAVs,Tractors - Number of Person...       629.0      1795.0
# Trucks, Tempos,MAVs,Tractors - Number of Person...    2.260303    3.443102
# Trucks, Tempos,MAVs,Tractors - Number of Person...      1290.0      4534.0
# Trucks, Tempos,MAVs,Tractors - Number of Person...    7.362711    9.714299
# Other Motor Vehicles - Number of Road Accidents...       198.0       760.0
# Other Motor Vehicles - Number of Road Accidents...    1.198504    1.578783
# Other Motor Vehicles - Number of Road Accidents...       578.0      1763.0
# Other Motor Vehicles - Number of Road Accidents...    3.489761    5.013518
# Other Motor Vehicles - Number of Persons - Kill...       215.0       793.0
# Other Motor Vehicles - Number of Persons - Kill...    1.285027    1.835141
# Other Motor Vehicles - Number of Persons - Inju...       323.0      1626.0
# Other Motor Vehicles - Number of Persons - Inju...    2.877733    5.032021
# Other Vehicles/Objects - Number of Road Acciden...        35.0       491.0
# Other Vehicles/Objects - Number of Road Acciden...    0.381065    0.998438
# Other Vehicles/Objects - Number of Road Acciden...       242.0      1514.0
# Other Vehicles/Objects - Number of Road Acciden...    1.091195    2.627482
# Other Vehicles/Objects - Number of Persons - Ki...        35.0       672.0
# Other Vehicles/Objects - Number of Persons - Ki...    0.408284    1.286627
# Other Vehicles/Objects - Number of Persons - In...       141.0      1165.0
# Other Vehicles/Objects - Number of Persons - In...    0.852905    2.459424
# Population                                          25351462.0  60439692.0
#
#                                                              max
# Sl. No.                                                      NaN
# States/UTs                                                   NaN
# Two-Wheelers - Number of Road Accidents - Fatal...       30064.0
# Two-Wheelers - Number of Road Accidents - Fatal...      8.912992
# Two-Wheelers - Number of Road Accidents - Total...      133634.0
# Two-Wheelers - Number of Road Accidents - Total...    130.746737
# Two-Wheelers - Number of Persons - Killed - 2014         32524.0
# Two-Wheelers - Number of Persons - Killed - 201...      9.187238
# Two-Wheelers - Number of Persons - Injured - 2014       127452.0
# Two-Wheelers - Number of Persons - Injured - 20...     57.454518
# Auto-Rickshaws - Number of Road Accidents - Fat...        5553.0
# Auto-Rickshaws - Number of Road Accidents - Fat...      3.350522
# Auto-Rickshaws - Number of Road Accidents - Tot...       31172.0
# Auto-Rickshaws - Number of Road Accidents - Tot...     15.078102
# Auto-Rickshaws - Number of Persons - Killed - 2014        6279.0
# Auto-Rickshaws - Number of Persons - Killed - 2...      4.413949
# Auto-Rickshaws - Number of Persons - Injured - ...       40848.0
# Auto-Rickshaws - Number of Persons - Injured - ...     19.141678
# Cars, Jeeps,Taxis - Number of Road Accidents - ...       22803.0
# Cars, Jeeps,Taxis - Number of Road Accidents - ...      5.896062
# Cars, Jeeps,Taxis - Number of Road Accidents - ...      111218.0
# Cars, Jeeps,Taxis - Number of Road Accidents - ...      94.20347
# Cars, Jeeps,Taxis - Number of Persons - Killed ...       26038.0
# Cars, Jeeps,Taxis - Number of Persons - Killed ...       6.71496
# Cars, Jeeps,Taxis - Number of Persons - Injured...      113413.0
# Cars, Jeeps,Taxis - Number of Persons - Injured...     37.014169
# Buses - Number of Road Accidents - Fatal - 2014          10710.0
# Buses - Number of Road Accidents - Fatal - 2014...      2.536487
# Buses - Number of Road Accidents - Total - 2014          41365.0
# Buses - Number of Road Accidents - Total - 2014...     24.270763
# Buses - Number of Persons - Killed - 2014                12185.0
# Buses - Number of Persons - Killed - 2014 per 1...      2.748554
# Buses - Number of Persons - Injured - 2014               51356.0
# Buses - Number of Persons - Injured - 2014 per ...     21.118922
# Trucks, Tempos,MAVs,Tractors - Number of Road A...       32081.0
# Trucks, Tempos,MAVs,Tractors - Number of Road A...      6.400763
# Trucks, Tempos,MAVs,Tractors - Number of Road A...       96215.0
# Trucks, Tempos,MAVs,Tractors - Number of Road A...     21.596865
# Trucks, Tempos,MAVs,Tractors - Number of Person...       35711.0
# Trucks, Tempos,MAVs,Tractors - Number of Person...      6.982651
# Trucks, Tempos,MAVs,Tractors - Number of Person...       94532.0
# Trucks, Tempos,MAVs,Tractors - Number of Person...     19.221898
# Other Motor Vehicles - Number of Road Accidents...       14603.0
# Other Motor Vehicles - Number of Road Accidents...      2.998607
# Other Motor Vehicles - Number of Road Accidents...       43981.0
# Other Motor Vehicles - Number of Road Accidents...      9.067801
# Other Motor Vehicles - Number of Persons - Kill...       15380.0
# Other Motor Vehicles - Number of Persons - Kill...      3.076899
# Other Motor Vehicles - Number of Persons - Inju...       39006.0
# Other Motor Vehicles - Number of Persons - Inju...     23.514305
# Other Vehicles/Objects - Number of Road Acciden...       10014.0
# Other Vehicles/Objects - Number of Road Acciden...       3.95522
# Other Vehicles/Objects - Number of Road Acciden...       31815.0
# Other Vehicles/Objects - Number of Road Acciden...     16.591878
# Other Vehicles/Objects - Number of Persons - Ki...       11554.0
# Other Vehicles/Objects - Number of Persons - Ki...      4.002873
# Other Vehicles/Objects - Number of Persons - In...       26867.0
# Other Vehicles/Objects - Number of Persons - In...     10.465846
# Population                                          1210854977.0

# %%
# Cell 3: create an aggregated "per-1L" accidents score and a binary label HighAccident
# Heuristic:
#  - find all numeric columns whose name contains "per 1L" or "per1L" (case-insensitive).
#  - sum them into a single metric 'accidents_per_1L_sum'
#  - create binary label 'HighAccident' = 1 if above median else 0

# find candidates
per1l_cols = [c for c in df.columns if isinstance(c, str) and ("per 1l" in c.lower() or "per1l" in c.lower() or "per 100000" in c.lower())]
# also include columns with 'per 1L people' or 'per 1L' etc.
if not per1l_cols:
    # backup: include any numeric column with 'per' in name
    per1l_cols = [c for c in df.columns if isinstance(c, str) and "per" in c.lower() and pd.api.types.is_numeric_dtype(df[c])]

print("Per-1L candidate columns ({}):".format(len(per1l_cols)))
for c in per1l_cols:
    print(" -", c)

if not per1l_cols:
    # fallback: choose an obvious numeric total column if present
    fallback = [c for c in df.columns if 'Total' in c and pd.api.types.is_numeric_dtype(df[c])]
    if fallback:
        per1l_cols = [fallback[0]]
        print("No per-1L columns found — using fallback:", fallback[0])
    else:
        raise RuntimeError("Couldn't find suitable numeric columns to build a label. Inspect your dataset manually.")

# create aggregated metric (sum of selected per-1L numeric columns)
df['accidents_per_1L_sum'] = df[per1l_cols].select_dtypes(include='number').sum(axis=1)

# create binary label by median threshold (ensures approx balanced classes)
median_val = df['accidents_per_1L_sum'].median()
df['HighAccident'] = (df['accidents_per_1L_sum'] > median_val).astype(int)

print("Created 'accidents_per_1L_sum' and binary label 'HighAccident' (median={:.4f})".format(median_val))
display(df[['accidents_per_1L_sum', 'HighAccident']].head(10))
print("Label distribution:")
print(df['HighAccident'].value_counts())
# Out:
# Per-1L candidate columns (28):
#  - Two-Wheelers - Number of Road Accidents - Fatal - 2014 per 1L people
#  - Two-Wheelers - Number of Road Accidents - Total - 2014 per 1L people
#  - Two-Wheelers - Number of Persons - Killed - 2014 per 1L people
#  - Two-Wheelers - Number of Persons - Injured - 2014 per 1L people
#  - Auto-Rickshaws - Number of Road Accidents - Fatal - 2014 per 1L people
#  - Auto-Rickshaws - Number of Road Accidents - Total - 2014 per 1L people
#  - Auto-Rickshaws - Number of Persons - Killed - 2014 per 1L people
#  - Auto-Rickshaws - Number of Persons - Injured - 2014 per 1L people
#  - Cars, Jeeps,Taxis - Number of Road Accidents - Fatal - 2014 per 1L people
#  - Cars, Jeeps,Taxis - Number of Road Accidents - Total - 2014 per 1L people
#  - Cars, Jeeps,Taxis - Number of Persons - Killed - 2014 per 1L people
#  - Cars, Jeeps,Taxis - Number of Persons - Injured - 2014 per 1L people
#  - Buses - Number of Road Accidents - Fatal - 2014 per 1L people
#  - Buses - Number of Road Accidents - Total - 2014 per 1L people
#  - Buses - Number of Persons - Killed - 2014 per 1L people
#  - Buses - Number of Persons - Injured - 2014 per 1L people
#  - Trucks, Tempos,MAVs,Tractors - Number of Road Accidents - Fatal - 2014 per 1L people
#  - Trucks, Tempos,MAVs,Tractors - Number of Road Accidents - Total - 2014 per 1L people
#  - Trucks, Tempos,MAVs,Tractors - Number of Persons - Killed - 2014 per 1L people
#  - Trucks, Tempos,MAVs,Tractors - Number of Persons - Injured - 2014 per 1L people
#  - Other Motor Vehicles - Number of Road Accidents - Fatal - 2014 per 1L people
#  - Other Motor Vehicles - Number of Road Accidents - Total - 2014 per 1L people
#  - Other Motor Vehicles - Number of Persons - Killed - 2014 per 1L people
#  - Other Motor Vehicles - Number of Persons - Injured - 2014 per 1L people
#  - Other Vehicles/Objects - Number of Road Accidents - Fatal - 2014 per 1L people
#  - Other Vehicles/Objects - Number of Road Accidents - Total - 2014 per 1L people
#  - Other Vehicles/Objects - Number of Persons - Killed - 2014 per 1L people
#  - Other Vehicles/Objects - Number of Persons - Injured - 2014 per 1L people
# Created 'accidents_per_1L_sum' and binary label 'HighAccident' (median=101.2960)
#    accidents_per_1L_sum  HighAccident
# 0            132.713477             1
# 1             52.322460             0
# 2             58.752320             0
# 3             24.605317             0
# 4            135.328761             1
# 5            458.059230             1
# 6            101.296016             0
# 7            111.697700             1
# 8            155.347681             1
# 9            125.840204             1
# Label distribution:
# HighAccident
# 0    19
# 1    18
# Name: count, dtype: int64

# %%
# Cell 4: Preprocessing and train/test split
# Drop identifier-like columns and the target columns from features
# Adjust the drop list if your notebook has specific index/id columns
drop_like = ['Sl. No.', 'Sl No', 'Sl_No', 'Sl', 'States/UTs', 'State/UTs', 'States', 'State']  # common id-like names
features = [c for c in df.columns if c not in drop_like and c not in ['HighAccident', 'accidents_per_1L_sum']]

# Optionally drop any text-heavy or near-unique columns
# filter features to only those present (defensive)
features = [c for c in features if c in df.columns]

X = df[features].copy()
y = df['HighAccident'].copy()

print("Feature count:", len(X.columns))
print("Some features:", X.columns.tolist()[:20])

# quick cleaning: drop columns that are constant or all null
const_or_empty = [c for c in X.columns if X[c].nunique(dropna=True) <= 1 or X[c].isna().all()]
if const_or_empty:
    print("Dropping constant/empty:", const_or_empty)
    X = X.drop(columns=const_or_empty)

# separate numeric & categorical
numeric_cols = X.select_dtypes(include=['number']).columns.tolist()
cat_cols = X.select_dtypes(include=['object', 'category', 'bool']).columns.tolist()
print("Numeric cols:", numeric_cols)
print("Categorical cols:", cat_cols)

# If dataset small (it is ~37 rows), set test_size small but keep stratify
test_size = 0.2 if len(df) >= 10 else 0.25

# be careful: stratify requires both classes present in train/test. Our binary creation uses median -> both classes exist.
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=test_size, random_state=42, stratify=y
)
print("Train/test shapes:", X_train.shape, X_test.shape)
# Out:
# Feature count: 57
# Some features: ['Two-Wheelers - Number of Road Accidents - Fatal - 2014', 'Two-Wheelers - Number of Road Accidents - Fatal - 2014 per 1L people', 'Two-Wheelers - Number of Road Accidents - Total - 2014', 'Two-Wheelers - Number of Road Accidents - Total - 2014 per 1L people', 'Two-Wheelers - Number of Persons - Killed - 2014', 'Two-Wheelers - Number of Persons - Killed - 2014 per 1L people', 'Two-Wheelers - Number of Persons - Injured - 2014', 'Two-Wheelers - Number of Persons - Injured - 2014 per 1L people', 'Auto-Rickshaws - Number of Road Accidents - Fatal - 2014', 'Auto-Rickshaws - Number of Road Accidents - Fatal - 2014 per 1L people', 'Auto-Rickshaws - Number of Road Accidents - Total - 2014', 'Auto-Rickshaws - Number of Road Accidents - Total - 2014 per 1L people', 'Auto-Rickshaws - Number of Persons - Killed - 2014', 'Auto-Rickshaws - Number of Persons - Killed - 2014 per 1L people', 'Auto-Rickshaws - Number of Persons - Injured - 2014', 'Auto-Rickshaws - Number of Persons - Injured - 2014 per 1L people', 'Cars, Jeeps,Taxis - Number of Road Accidents - Fatal - 2014', 'Cars, Jeeps,Taxis - Number of Road Accidents - Fatal - 2014 per 1L people', 'Cars, Jeeps,Taxis - Number of Road Accidents - Total - 2014', 'Cars, Jeeps,Taxis - Number of Road Accidents - Total - 2014 per 1L people']
# Numeric cols: ['Two-Wheelers - Number of Road Accidents - Fatal - 2014', 'Two-Wheelers - Number of Road Accidents - Fatal - 2014 per 1L people', 'Two-Wheelers - Number of Road Accidents - Total - 2014', 'Two-Wheelers - Number of Road Accidents - Total - 2014 per 1L people', 'Two-Wheelers - Number of Persons - Killed - 2014', 'Two-Wheelers - Number of Persons - Killed - 2014 per 1L people', 'Two-Wheelers - Number of Persons - Injured - 2014', 'Two-Wheelers - Number of Persons - Injured - 2014 per 1L people', 'Auto-Rickshaws - Number of Road Accidents - Fatal - 2014', 'Auto-Rickshaws - Number of Road Accidents - Fatal - 2014 per 1L people', 'Auto-Rickshaws - Number of Road Accidents - Total - 2014', 'Auto-Rickshaws - Number of Road Accidents - Total - 2014 per 1L people', 'Auto-Rickshaws - Number of Persons - Killed - 2014', 'Auto-Rickshaws - Number of Persons - Killed - 2014 per 1L people', 'Auto-Rickshaws - Number of Persons - Injured - 2014', 'Auto-Rickshaws - Number of Persons - Injured - 2014 per 1L people', 'Cars, Jeeps,Taxis - Number of Road Accidents - Fatal - 2014', 'Cars, Jeeps,Taxis - Number of Road Accidents - Fatal - 2014 per 1L people', 'Cars, Jeeps,Taxis - Number of Road Accidents - Total - 2014', 'Cars, Jeeps,Taxis - Number of Road Accidents - Total - 2014 per 1L people', 'Cars, Jeeps,Taxis - Number of Persons - Killed - 2014', 'Cars, Jeeps,Taxis - Number of Persons - Killed - 2014 per 1L people', 'Cars, Jeeps,Taxis - Number of Persons - Injured - 2014', 'Cars, Jeeps,Taxis - Number of Persons - Injured - 2014 per 1L people', 'Buses - Number of Road Accidents - Fatal - 2014', 'Buses - Number of Road Accidents - Fatal - 2014 per 1L people', 'Buses - Number of Road Accidents - Total - 2014', 'Buses - Number of Road Accidents - Total - 2014 per 1L people', 'Buses - Number of Persons - Killed - 2014', 'Buses - Number of Persons - Killed - 2014 per 1L people', 'Buses - Number of Persons - Injured - 2014', 'Buses - Number of Persons - Injured - 2014 per 1L people', 'Trucks, Tempos,MAVs,Tractors - Number of Road Accidents - Fatal - 2014', 'Trucks, Tempos,MAVs,Tractors - Number of Road Accidents - Fatal - 2014 per 1L people', 'Trucks, Tempos,MAVs,Tractors - Number of Road Accidents - Total - 2014', 'Trucks, Tempos,MAVs,Tractors - Number of Road Accidents - Total - 2014 per 1L people', 'Trucks, Tempos,MAVs,Tractors - Number of Persons - Killed - 2014', 'Trucks, Tempos,MAVs,Tractors - Number of Persons - Killed - 2014 per 1L people', 'Trucks, Tempos,MAVs,Tractors - Number of Persons - Injured - 2014', 'Trucks, Tempos,MAVs,Tractors - Number of Persons - Injured - 2014 per 1L people', 'Other Motor Vehicles - Number of Road Accidents - Fatal - 2014', 'Other Motor Vehicles - Number of Road Accidents - Fatal - 2014 per 1L people', 'Other Motor Vehicles - Number of Road Accidents - Total - 2014', 'Other Motor Vehicles - Number of Road Accidents - Total - 2014 per 1L people', 'Other Motor Vehicles - Number of Persons - Killed - 2014', 'Other Motor Vehicles - Number of Persons - Killed - 2014 per 1L people', 'Other Motor Vehicles - Number of Persons - Injured - 2014', 'Other Motor Vehicles - Number of Persons - Injured - 2014 per 1L people', 'Other Vehicles/Objects - Number of Road Accidents - Fatal - 2014', 'Other Vehicles/Objects - Number of Road Accidents - Fatal - 2014 per 1L people', 'Other Vehicles/Objects - Number of Road Accidents - Total - 2014', 'Other Vehicles/Objects - Number of Road Accidents - Total - 2014 per 1L people', 'Other Vehicles/Objects - Number of Persons - Killed - 2014', 'Other Vehicles/Objects - Number of Persons - Killed - 2014 per 1L people', 'Other Vehicles/Objects - Number of Persons - Injured - 2014', 'Other Vehicles/Objects - Number of Persons - Injured - 2014 per 1L people', 'Population']
# Categorical cols: []
# Train/test shapes: (29, 57) (8, 57)

# %%
# Cell 5: Build pipelines, train models, evaluate and save best
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
])
preprocessor = ColumnTransformer(transformers=[
    ('num', numeric_transformer, numeric_cols),
    ('cat', categorical_transformer, cat_cols)
], remainder='drop')

models = {
    "LogisticRegression": LogisticRegression(max_iter=2000),
    "RandomForest": RandomForestClassifier(n_estimators=200, random_state=42)
}

results = {}
best_name = None
best_score = -1
best_pipeline = None

for name, model in models.items():
    pipe = Pipeline(steps=[('pre', preprocessor), ('clf', model)])
    print(f"\nTraining {name} ...")
    pipe.fit(X_train, y_train)
    preds = pipe.predict(X_test)
    acc = accuracy_score(y_test, preds)
    try:
        prob = pipe.predict_proba(X_test)[:,1]
        auc = roc_auc_score(y_test, prob)
    except Exception:
        auc = None
    print(f"{name} -> accuracy: {acc:.4f}, AUC: {auc}")
    print("Classification report:")
    print(classification_report(y_test, preds, zero_division=0))
    cm = confusion_matrix(y_test, preds)
    print("Confusion matrix:\n", cm)
    results[name] = {'accuracy': acc, 'auc': auc, 'pipeline': pipe}
    if acc > best_score:
        best_score = acc
        best_name = name
        best_pipeline = pipe

print(f"\nBest model: {best_name} with accuracy {best_score:.4f}")
# Out:
# Training LogisticRegression ...
# LogisticRegression -> accuracy: 0.7500, AUC: 1.0
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         4
#            1       1.00      0.50      0.67         4
#
#     accuracy                           0.75         8
#    macro avg       0.83      0.75      0.73         8
# weighted avg       0.83      0.75      0.73         8
#
# Confusion matrix:
#  [[4 0]
#  [2 2]]
#
# Training RandomForest ...
# RandomForest -> accuracy: 0.8750, AUC: 0.9375
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89         4
#            1       1.00      0.75      0.86         4
#
#     accuracy                           0.88         8
#    macro avg       0.90      0.88      0.87         8
# weighted avg       0.90      0.88      0.87         8
#
# Confusion matrix:
#  [[4 0]
#  [1 3]]
#
# Best model: RandomForest with accuracy 0.8750

# %%
# Cell 6: Save best model pipeline and show how to load & predict later
out_path = r"C:\Users\KIIT\Desktop\1\RoadAccidentsInIndia\best_model.pkl"
to_save = {
    'model_pipeline': best_pipeline,
    'feature_columns': X.columns.tolist(),
    'label_name': 'HighAccident',
    'aggregation_cols_used_for_label': per1l_cols
}
with open(out_path, "wb") as f:
    pickle.dump(to_save, f)
print("Saved best pipeline to:", out_path)

# Usage example
print("""
To load and predict later:

import pickle
import pandas as pd
with open('/mnt/data/best_model.pkl','rb') as f:
    saved = pickle.load(f)
model = saved['model_pipeline']
# prepare new_X that has columns saved['feature_columns'] in same order
# preds = model.predict(new_X)
""")
# Out:
# Saved best pipeline to: C:\Users\KIIT\Desktop\1\RoadAccidentsInIndia\best_model.pkl
#
# To load and predict later:
#
# import pickle
# import pandas as pd
# with open('/mnt/data/best_model.pkl','rb') as f:
#     saved = pickle.load(f)
# model = saved['model_pipeline']
# # prepare new_X that has columns saved['feature_columns'] in same order
# # preds = model.predict(new_X)

# %%
# Show predicted labels for the test set using the best model pipeline
predicted_labels = best_pipeline.predict(X_test)
print("Predicted labels for test set:", predicted_labels)
print("True labels:", y_test.values)
# Out:
# Predicted labels for test set: [0 0 1 0 0 1 0 1]
# True labels: [0 0 1 1 0 1 0 1]

# %%
# Explanation of binary labels used in this notebook
mapping = {
    0: f"LowAccident  -> accidents_per_1L_sum <= median ({median_val:.4f})",
    1: f"HighAccident -> accidents_per_1L_sum >  median ({median_val:.4f})"
}

print("Binary label meaning:")
for k, v in mapping.items():
    print(f" {k} : {v}")

print("\nClass distribution in 'HighAccident':")
print(y.value_counts().sort_index())

# show a few examples from each class
print("\nExamples (accidents_per_1L_sum, HighAccident):")
display(df.loc[y==1, ['accidents_per_1L_sum', 'HighAccident']].head(3))
display(df.loc[y==0, ['accidents_per_1L_sum', 'HighAccident']].head(3))
# Out:
# Binary label meaning:
#  0 : LowAccident  -> accidents_per_1L_sum <= median (101.2960)
#  1 : HighAccident -> accidents_per_1L_sum >  median (101.2960)
#
# Class distribution in 'HighAccident':
# HighAccident
# 0    19
# 1    18
# Name: count, dtype: int64
#
# Examples (accidents_per_1L_sum, HighAccident):
#    accidents_per_1L_sum  HighAccident
# 0            132.713477             1
# 4            135.328761             1
# 5            458.059230             1
#    accidents_per_1L_sum  HighAccident
# 1             52.322460             0
# 2             58.752320             0
# 3             24.605317             0
